# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.mixture import GaussianMixture
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split



from keras.models import Sequential
from keras import Input
from keras.losses import binary_crossentropy
from keras.layers import Dense, Dropout
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
# Out:
# 2023-09-22 17:25:47.490045: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-22 17:25:47.550133: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-22 17:25:47.551041: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-22 17:25:48.779620: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
state0=np.load('../Data/new/2gsps/state0.npy')
state1=np.load('../Data/new/2gsps/state1.npy')
output0=np.zeros((state0.shape[0]))
output1=np.ones((state1.shape[0]))
print(state0.shape)
# Out:
# (1000, 8192, 2)

# %%
x=np.vstack((state0,state1))
print(x.shape)
y=np.hstack((output0,output1))
print(y.shape)
# Out:
# (2000, 8192, 2)
# (2000,)

# %%
st,ed=1600,2600
x_train, x_test, y_train, y_test = train_test_split(x[:,st:ed,:], y, test_size=0.30, random_state=45)
print(x_train.shape)
print(y_train.sum())

x_train=np.mean(x_train,axis=1)
x_test=np.mean(x_test,axis=1)

# x_train=x_train.reshape((x_train.shape[0],x_train.shape[1]*2))
# x_test=x_test.reshape((x_test.shape[0],x_test.shape[1]*2))
print(x_train.shape)
# Out:
# (1400, 1000, 2)
# 704.0
# (1400, 2)

# %% [markdown]
# ## Logistic Regression

# %%
# x_trainC=x_train.reshape((x_train.shape[0],x_train.shape[1]*2))
# x_testC=x_test.reshape((x_test.shape[0],x_test.shape[1]*2))
classifier = LogisticRegression(random_state = 42, max_iter=500)
classifier.fit(x_train, y_train)
print(classifier.score(x_test,y_test))
pred = classifier.predict(x_test)
# Out:
# 0.8183333333333334

# %% [markdown]
# ## SVM

# %%
model=SVC(decision_function_shape='ovo')
model.fit(x_train,y_train)
print(model.score(x_test,y_test))
# Out:
# 0.945

# %% [markdown]
# ## GMM

# %%
Y=list(zip(np.append(np.mean(state0[:,2000:3000,0],axis=1),np.mean(state1[:,2000:3000,0],axis=1)),np.append(np.mean(state0[:,2000:3000,1],axis=1),np.mean(state1[:,2000:3000,1],axis=1))))
gmm_Y=GaussianMixture(n_components=2,covariance_type='full').fit(Y)
bitstring=np.split(gmm_Y.predict(Y),2)
print('P(0|0)=',len(bitstring[0][bitstring[0]==0])/len(bitstring[0]))
print('P(1|1)=',len(bitstring[1][bitstring[1]==1])/len(bitstring[1]))
X=list(zip(np.mean(state0[:,2000:3000,0],axis=1),np.mean(state0[:,2000:3000,1],axis=1)))
gmm_Y_1=GaussianMixture(n_components=1,covariance_type='spherical').fit(X)
X=list(zip(np.mean(state1[:,2000:3000,0],axis=1),np.mean(state1[:,2000:3000,1],axis=1)))
gmm_Y_2=GaussianMixture(n_components=1,covariance_type='spherical').fit(X)
# Out:
# P(0|0)= 0.138
# P(1|1)= 0.134

# %% [markdown]
# ## NN

# %%
def arch():
    model=Sequential()
    model.add(Input(shape=(2)))
    model.add(Dense(32,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(16,activation='relu'))
    model.add(Dropout(0.5))
    # model.add(Dense(16,activation='relu'))
    # # model.add(Dropout(0.8))
    # model.add(Dense(16,activation='relu'))
    # # model.add(Dropout(0.8))
    # model.add(Dense(32,activation='relu'))
    # # model.add(Dropout(0.8))
    # model.add(Dense(16,activation='relu'))
    # # model.add(Dropout(0.8))
    # model.add(Dense(4,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    return model
# arch().summary()

# %%
import keras.backend as K

def bceloss(y_true, y_pred):
    # Clip the prediction value to prevent log(0) error
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    # Calculate the weighted binary cross entropy loss
    loss = -(0.1 * (y_true * K.log(y_pred)) + 0.9*((1 - y_true) * K.log(1 - y_pred)))
    return K.mean(loss, axis=-1)

model=arch()
model.summary
opt=SGD( learning_rate=0.01, momentum=0.9)
model.compile(loss=binary_crossentropy, optimizer='adam', metrics=['accuracy'])
model_path="../Model/NN2/{epoch:02d}-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
H=model.fit(x_train,y_train,
          validation_data=(x_test, y_test),
          epochs=100,batch_size=32,
          callbacks=callbacks_list,
          verbose=1)
# Out:
# Epoch 1/100
# 34/44 [======================>.......] - ETA: 0s - loss: 8.9929 - accuracy: 0.5018
# Epoch 1: val_accuracy improved from -inf to 0.73500, saving model to ../Model/NN2/01-0.7350.h5
# 44/44 [==============================] - 1s 5ms/step - loss: 7.8560 - accuracy: 0.5314 - val_loss: 0.7816 - val_accuracy: 0.7350
# Epoch 2/100
# 37/44 [========================>.....] - ETA: 0s - loss: 3.2240 - accuracy: 0.6461
# Epoch 2: val_accuracy improved from 0.73500 to 0.94167, saving model to ../Model/NN2/02-0.9417.h5
# 44/44 [==============================] - 0s 3ms/step - loss: 2.9769 - accuracy: 0.6621 - val_loss: 0.5085 - val_accuracy: 0.9417
# Epoch 3/100
# 42/44 [===========================>..] - ETA: 0s - loss: 2.1768 - accuracy: 0.7545
# Epoch 3: val_accuracy improved from 0.94167 to 0.94333, saving model to ../Model/NN2/03-0.9433.h5
# 44/44 [==============================] - 0s 3ms/step - loss: 2.1121 - accuracy: 0.7586 - val_loss: 0.4517 - val_accuracy: 0.9433
# Epoch 4/100
# 42/44 [===========================>..] - ETA: 0s - loss: 1.9100 - accuracy: 0.7716
# Epoch 4: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 1.8709 - accuracy: 0.7714 - val_loss: 0.3550 - val_accuracy: 0.9417
# Epoch 5/100
#  1/44 [..............................] - ETA: 0s - loss: 1.3817 - accuracy: 0.8438
# Epoch 5: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 1.4703 - accuracy: 0.7964 - val_loss: 0.3045 - val_accuracy: 0.9400
# Epoch 6/100
#  1/44 [..............................] - ETA: 0s - loss: 1.4394 - accuracy: 0.7812
# Epoch 6: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 1.3009 - accuracy: 0.7879 - val_loss: 0.2723 - val_accuracy: 0.9400
# Epoch 7/100
# 41/44 [==========================>...] - ETA: 0s - loss: 1.2538 - accuracy: 0.7881
# Epoch 7: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 1.2560 - accuracy: 0.7914 - val_loss: 0.2526 - val_accuracy: 0.9383
# Epoch 8/100
# 40/44 [==========================>...] - ETA: 0s - loss: 0.9384 - accuracy: 0.8078
# Epoch 8: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.9025 - accuracy: 0.8129 - val_loss: 0.2518 - val_accuracy: 0.9333
# Epoch 9/100
# 40/44 [==========================>...] - ETA: 0s - loss: 0.9116 - accuracy: 0.8039
# Epoch 9: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.9017 - accuracy: 0.8064 - val_loss: 0.2621 - val_accuracy: 0.9350
# Epoch 10/100
# 44/44 [==============================] - ETA: 0s - loss: 0.6795 - accuracy: 0.8179
# Epoch 10: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6795 - accuracy: 0.8179 - val_loss: 0.2826 - val_accuracy: 0.9383
# Epoch 11/100
#  1/44 [..............................] - ETA: 0s - loss: 1.5104 - accuracy: 0.7812
# Epoch 11: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.7752 - accuracy: 0.8107 - val_loss: 0.2920 - val_accuracy: 0.9350
# Epoch 12/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3620 - accuracy: 0.7812
# Epoch 12: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6729 - accuracy: 0.8221 - val_loss: 0.2938 - val_accuracy: 0.9350
# Epoch 13/100
# 32/44 [====================>.........] - ETA: 0s - loss: 0.5856 - accuracy: 0.8262
# Epoch 13: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 3ms/step - loss: 0.6227 - accuracy: 0.8207 - val_loss: 0.3102 - val_accuracy: 0.9350
# Epoch 14/100
# 40/44 [==========================>...] - ETA: 0s - loss: 0.5485 - accuracy: 0.8141
# Epoch 14: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5699 - accuracy: 0.8121 - val_loss: 0.3146 - val_accuracy: 0.9333
# Epoch 15/100
# 43/44 [============================>.] - ETA: 0s - loss: 0.5894 - accuracy: 0.8241
# Epoch 15: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.8250 - val_loss: 0.3323 - val_accuracy: 0.9367
# Epoch 16/100
#  1/44 [..............................] - ETA: 0s - loss: 0.5001 - accuracy: 0.8438
# Epoch 16: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5698 - accuracy: 0.8279 - val_loss: 0.3404 - val_accuracy: 0.9367
# Epoch 17/100
# 44/44 [==============================] - ETA: 0s - loss: 0.4906 - accuracy: 0.8407
# Epoch 17: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4906 - accuracy: 0.8407 - val_loss: 0.3273 - val_accuracy: 0.9333
# Epoch 18/100
# 38/44 [========================>.....] - ETA: 0s - loss: 0.5459 - accuracy: 0.8215
# Epoch 18: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5372 - accuracy: 0.8214 - val_loss: 0.3201 - val_accuracy: 0.9333
# Epoch 19/100
# 33/44 [=====================>........] - ETA: 0s - loss: 0.5257 - accuracy: 0.8220
# Epoch 19: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5029 - accuracy: 0.8257 - val_loss: 0.3270 - val_accuracy: 0.9350
# Epoch 20/100
# 39/44 [=========================>....] - ETA: 0s - loss: 0.5496 - accuracy: 0.8149
# Epoch 20: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5434 - accuracy: 0.8186 - val_loss: 0.3360 - val_accuracy: 0.9383
# Epoch 21/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4677 - accuracy: 0.7812
# Epoch 21: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5152 - accuracy: 0.8357 - val_loss: 0.3490 - val_accuracy: 0.9383
# Epoch 22/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3460 - accuracy: 0.8750
# Epoch 22: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5012 - accuracy: 0.8407 - val_loss: 0.3380 - val_accuracy: 0.9383
# Epoch 23/100
#  1/44 [..............................] - ETA: 0s - loss: 0.7153 - accuracy: 0.8438
# Epoch 23: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.8386 - val_loss: 0.3296 - val_accuracy: 0.9350
# Epoch 24/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4167 - accuracy: 0.7812
# Epoch 24: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4534 - accuracy: 0.8564 - val_loss: 0.3299 - val_accuracy: 0.9317
# Epoch 25/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4950 - accuracy: 0.8438
# Epoch 25: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.8507 - val_loss: 0.3391 - val_accuracy: 0.9383
# Epoch 26/100
#  1/44 [..............................] - ETA: 0s - loss: 0.8859 - accuracy: 0.7500
# Epoch 26: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.8507 - val_loss: 0.3337 - val_accuracy: 0.9367
# Epoch 27/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3291 - accuracy: 0.8750
# Epoch 27: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.8571 - val_loss: 0.3343 - val_accuracy: 0.9383
# Epoch 28/100
#  1/44 [..............................] - ETA: 0s - loss: 0.5516 - accuracy: 0.8750
# Epoch 28: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.8636 - val_loss: 0.3328 - val_accuracy: 0.9383
# Epoch 29/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2921 - accuracy: 0.8750
# Epoch 29: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.8536 - val_loss: 0.3354 - val_accuracy: 0.9400
# Epoch 30/100
#  1/44 [..............................] - ETA: 0s - loss: 0.5709 - accuracy: 0.7812
# Epoch 30: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4466 - accuracy: 0.8521 - val_loss: 0.3297 - val_accuracy: 0.9400
# Epoch 31/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4145 - accuracy: 0.8750
# Epoch 31: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4270 - accuracy: 0.8564 - val_loss: 0.3188 - val_accuracy: 0.9400
# Epoch 32/100
#  1/44 [..............................] - ETA: 0s - loss: 0.5845 - accuracy: 0.7812
# Epoch 32: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.8507 - val_loss: 0.3140 - val_accuracy: 0.9383
# Epoch 33/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4613 - accuracy: 0.8750
# Epoch 33: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8650 - val_loss: 0.3085 - val_accuracy: 0.9367
# Epoch 34/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4536 - accuracy: 0.8750
# Epoch 34: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4209 - accuracy: 0.8679 - val_loss: 0.3071 - val_accuracy: 0.9367
# Epoch 35/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4863 - accuracy: 0.8438
# Epoch 35: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8714 - val_loss: 0.3040 - val_accuracy: 0.9367
# Epoch 36/100
#  1/44 [..............................] - ETA: 0s - loss: 0.5270 - accuracy: 0.8125
# Epoch 36: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.8643 - val_loss: 0.3042 - val_accuracy: 0.9383
# Epoch 37/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4047 - accuracy: 0.8750
# Epoch 37: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8757 - val_loss: 0.2956 - val_accuracy: 0.9367
# Epoch 38/100
#  1/44 [..............................] - ETA: 0s - loss: 0.5042 - accuracy: 0.8125
# Epoch 38: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4071 - accuracy: 0.8857 - val_loss: 0.2972 - val_accuracy: 0.9367
# Epoch 39/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2216 - accuracy: 0.9375
# Epoch 39: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.8679 - val_loss: 0.2933 - val_accuracy: 0.9367
# Epoch 40/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3186 - accuracy: 0.9062
# Epoch 40: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8807 - val_loss: 0.2781 - val_accuracy: 0.9367
# Epoch 41/100
#  1/44 [..............................] - ETA: 0s - loss: 0.6286 - accuracy: 0.8438
# Epoch 41: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8693 - val_loss: 0.2890 - val_accuracy: 0.9367
# Epoch 42/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2657 - accuracy: 0.9375
# Epoch 42: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8729 - val_loss: 0.2845 - val_accuracy: 0.9367
# Epoch 43/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4540 - accuracy: 0.8750
# Epoch 43: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.8650 - val_loss: 0.2796 - val_accuracy: 0.9367
# Epoch 44/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3973 - accuracy: 0.8438
# Epoch 44: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3964 - accuracy: 0.8771 - val_loss: 0.2722 - val_accuracy: 0.9367
# Epoch 45/100
# 39/44 [=========================>....] - ETA: 0s - loss: 0.3811 - accuracy: 0.8838
# Epoch 45: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8779 - val_loss: 0.2735 - val_accuracy: 0.9367
# Epoch 46/100
# 31/44 [====================>.........] - ETA: 0s - loss: 0.4309 - accuracy: 0.8609
# Epoch 46: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4022 - accuracy: 0.8750 - val_loss: 0.2824 - val_accuracy: 0.9367
# Epoch 47/100
# 35/44 [======================>.......] - ETA: 0s - loss: 0.3739 - accuracy: 0.8804
# Epoch 47: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8779 - val_loss: 0.2649 - val_accuracy: 0.9367
# Epoch 48/100
# 43/44 [============================>.] - ETA: 0s - loss: 0.3889 - accuracy: 0.8786
# Epoch 48: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8800 - val_loss: 0.2671 - val_accuracy: 0.9367
# Epoch 49/100
# 34/44 [======================>.......] - ETA: 0s - loss: 0.4097 - accuracy: 0.8879
# Epoch 49: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4096 - accuracy: 0.8864 - val_loss: 0.2792 - val_accuracy: 0.9367
# Epoch 50/100
# 33/44 [=====================>........] - ETA: 0s - loss: 0.4138 - accuracy: 0.8807
# Epoch 50: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3961 - accuracy: 0.8786 - val_loss: 0.2759 - val_accuracy: 0.9367
# Epoch 51/100
# 39/44 [=========================>....] - ETA: 0s - loss: 0.3991 - accuracy: 0.8806
# Epoch 51: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8807 - val_loss: 0.2695 - val_accuracy: 0.9367
# Epoch 52/100
# 32/44 [====================>.........] - ETA: 0s - loss: 0.4018 - accuracy: 0.8877
# Epoch 52: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3866 - accuracy: 0.8850 - val_loss: 0.2576 - val_accuracy: 0.9350
# Epoch 53/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3109 - accuracy: 0.9062
# Epoch 53: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8829 - val_loss: 0.2589 - val_accuracy: 0.9367
# Epoch 54/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3840 - accuracy: 0.9062
# Epoch 54: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8800 - val_loss: 0.2618 - val_accuracy: 0.9367
# Epoch 55/100
# 43/44 [============================>.] - ETA: 0s - loss: 0.3853 - accuracy: 0.8765
# Epoch 55: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8750 - val_loss: 0.2617 - val_accuracy: 0.9367
# Epoch 56/100
# 37/44 [========================>.....] - ETA: 0s - loss: 0.4091 - accuracy: 0.8809
# Epoch 56: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8843 - val_loss: 0.2696 - val_accuracy: 0.9367
# Epoch 57/100
# 40/44 [==========================>...] - ETA: 0s - loss: 0.3922 - accuracy: 0.8906
# Epoch 57: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8871 - val_loss: 0.2699 - val_accuracy: 0.9383
# Epoch 58/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2960 - accuracy: 0.8438
# Epoch 58: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8907 - val_loss: 0.2628 - val_accuracy: 0.9383
# Epoch 59/100
# 37/44 [========================>.....] - ETA: 0s - loss: 0.3935 - accuracy: 0.8902
# Epoch 59: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.8914 - val_loss: 0.2629 - val_accuracy: 0.9383
# Epoch 60/100
# 40/44 [==========================>...] - ETA: 0s - loss: 0.3770 - accuracy: 0.8898
# Epoch 60: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.8921 - val_loss: 0.2568 - val_accuracy: 0.9383
# Epoch 61/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2415 - accuracy: 0.9062
# Epoch 61: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3840 - accuracy: 0.8921 - val_loss: 0.2639 - val_accuracy: 0.9383
# Epoch 62/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2573 - accuracy: 0.9375
# Epoch 62: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8929 - val_loss: 0.2667 - val_accuracy: 0.9367
# Epoch 63/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3895 - accuracy: 0.7812
# Epoch 63: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3791 - accuracy: 0.8921 - val_loss: 0.2551 - val_accuracy: 0.9367
# Epoch 64/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3603 - accuracy: 0.9062
# Epoch 64: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3759 - accuracy: 0.9000 - val_loss: 0.2499 - val_accuracy: 0.9350
# Epoch 65/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3024 - accuracy: 0.9062
# Epoch 65: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3796 - accuracy: 0.8979 - val_loss: 0.2503 - val_accuracy: 0.9400
# Epoch 66/100
# 41/44 [==========================>...] - ETA: 0s - loss: 0.3851 - accuracy: 0.8857
# Epoch 66: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3880 - accuracy: 0.8857 - val_loss: 0.2600 - val_accuracy: 0.9367
# Epoch 67/100
# 44/44 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8971
# Epoch 67: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8971 - val_loss: 0.2460 - val_accuracy: 0.9383
# Epoch 68/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2460 - accuracy: 0.9062
# Epoch 68: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3900 - accuracy: 0.9007 - val_loss: 0.2596 - val_accuracy: 0.9383
# Epoch 69/100
# 38/44 [========================>.....] - ETA: 0s - loss: 0.3731 - accuracy: 0.8923
# Epoch 69: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3667 - accuracy: 0.8950 - val_loss: 0.2548 - val_accuracy: 0.9383
# Epoch 70/100
# 42/44 [===========================>..] - ETA: 0s - loss: 0.3775 - accuracy: 0.8906
# Epoch 70: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8914 - val_loss: 0.2531 - val_accuracy: 0.9367
# Epoch 71/100
# 42/44 [===========================>..] - ETA: 0s - loss: 0.3716 - accuracy: 0.8958
# Epoch 71: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3703 - accuracy: 0.8964 - val_loss: 0.2483 - val_accuracy: 0.9383
# Epoch 72/100
# 39/44 [=========================>....] - ETA: 0s - loss: 0.3639 - accuracy: 0.8966
# Epoch 72: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8964 - val_loss: 0.2515 - val_accuracy: 0.9400
# Epoch 73/100
# 44/44 [==============================] - ETA: 0s - loss: 0.3662 - accuracy: 0.8993
# Epoch 73: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3662 - accuracy: 0.8993 - val_loss: 0.2454 - val_accuracy: 0.9400
# Epoch 74/100
# 40/44 [==========================>...] - ETA: 0s - loss: 0.3711 - accuracy: 0.8977
# Epoch 74: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3742 - accuracy: 0.8971 - val_loss: 0.2452 - val_accuracy: 0.9400
# Epoch 75/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2145 - accuracy: 0.9688
# Epoch 75: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8943 - val_loss: 0.2432 - val_accuracy: 0.9383
# Epoch 76/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3852 - accuracy: 0.8438
# Epoch 76: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3803 - accuracy: 0.8950 - val_loss: 0.2494 - val_accuracy: 0.9383
# Epoch 77/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3036 - accuracy: 0.9688
# Epoch 77: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.9036 - val_loss: 0.2402 - val_accuracy: 0.9383
# Epoch 78/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2419 - accuracy: 0.9688
# Epoch 78: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.9000 - val_loss: 0.2366 - val_accuracy: 0.9383
# Epoch 79/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2787 - accuracy: 0.9375
# Epoch 79: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.9014 - val_loss: 0.2455 - val_accuracy: 0.9400
# Epoch 80/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3145 - accuracy: 0.8438
# Epoch 80: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8950 - val_loss: 0.2531 - val_accuracy: 0.9383
# Epoch 81/100
#  1/44 [..............................] - ETA: 0s - loss: 0.5049 - accuracy: 0.8438
# Epoch 81: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3663 - accuracy: 0.8964 - val_loss: 0.2465 - val_accuracy: 0.9383
# Epoch 82/100
# 40/44 [==========================>...] - ETA: 0s - loss: 0.3559 - accuracy: 0.9023
# Epoch 82: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.9007 - val_loss: 0.2420 - val_accuracy: 0.9400
# Epoch 83/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3764 - accuracy: 0.8750
# Epoch 83: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8986 - val_loss: 0.2429 - val_accuracy: 0.9383
# Epoch 84/100
# 44/44 [==============================] - ETA: 0s - loss: 0.3598 - accuracy: 0.9014
# Epoch 84: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3598 - accuracy: 0.9014 - val_loss: 0.2463 - val_accuracy: 0.9383
# Epoch 85/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3716 - accuracy: 0.9062
# Epoch 85: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3849 - accuracy: 0.9064 - val_loss: 0.2482 - val_accuracy: 0.9383
# Epoch 86/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2045 - accuracy: 0.9688
# Epoch 86: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3695 - accuracy: 0.9050 - val_loss: 0.2527 - val_accuracy: 0.9383
# Epoch 87/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3793 - accuracy: 0.8438
# Epoch 87: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3567 - accuracy: 0.9021 - val_loss: 0.2379 - val_accuracy: 0.9400
# Epoch 88/100
# 39/44 [=========================>....] - ETA: 0s - loss: 0.3638 - accuracy: 0.8974
# Epoch 88: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.9007 - val_loss: 0.2456 - val_accuracy: 0.9400
# Epoch 89/100
#  1/44 [..............................] - ETA: 0s - loss: 0.1830 - accuracy: 0.9375
# Epoch 89: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8993 - val_loss: 0.2396 - val_accuracy: 0.9400
# Epoch 90/100
# 44/44 [==============================] - ETA: 0s - loss: 0.3477 - accuracy: 0.9000
# Epoch 90: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3477 - accuracy: 0.9000 - val_loss: 0.2349 - val_accuracy: 0.9400
# Epoch 91/100
# 43/44 [============================>.] - ETA: 0s - loss: 0.3606 - accuracy: 0.9092
# Epoch 91: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3606 - accuracy: 0.9086 - val_loss: 0.2384 - val_accuracy: 0.9400
# Epoch 92/100
# 43/44 [============================>.] - ETA: 0s - loss: 0.3739 - accuracy: 0.9033
# Epoch 92: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.9036 - val_loss: 0.2461 - val_accuracy: 0.9400
# Epoch 93/100
# 41/44 [==========================>...] - ETA: 0s - loss: 0.3581 - accuracy: 0.9116
# Epoch 93: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.9107 - val_loss: 0.2422 - val_accuracy: 0.9400
# Epoch 94/100
#  1/44 [..............................] - ETA: 0s - loss: 0.4242 - accuracy: 0.9375
# Epoch 94: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.9050 - val_loss: 0.2407 - val_accuracy: 0.9400
# Epoch 95/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2383 - accuracy: 0.9688
# Epoch 95: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.9057 - val_loss: 0.2431 - val_accuracy: 0.9400
# Epoch 96/100
# 41/44 [==========================>...] - ETA: 0s - loss: 0.3726 - accuracy: 0.9009
# Epoch 96: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8993 - val_loss: 0.2451 - val_accuracy: 0.9400
# Epoch 97/100
# 40/44 [==========================>...] - ETA: 0s - loss: 0.3503 - accuracy: 0.9055
# Epoch 97: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.9050 - val_loss: 0.2397 - val_accuracy: 0.9400
# Epoch 98/100
# 43/44 [============================>.] - ETA: 0s - loss: 0.3595 - accuracy: 0.9026
# Epoch 98: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3597 - accuracy: 0.9014 - val_loss: 0.2426 - val_accuracy: 0.9400
# Epoch 99/100
#  1/44 [..............................] - ETA: 0s - loss: 0.2169 - accuracy: 0.9375
# Epoch 99: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.9036 - val_loss: 0.2469 - val_accuracy: 0.9400
# Epoch 100/100
#  1/44 [..............................] - ETA: 0s - loss: 0.3013 - accuracy: 0.9062
# Epoch 100: val_accuracy did not improve from 0.94333
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3549 - accuracy: 0.9043 - val_loss: 0.2338 - val_accuracy: 0.9400

# %%
count=0
count1=0
y_pred=model.predict(x_test)
for i in range(y_pred.shape[0]):
    if y_test[i]==0:
        count+=1
        if y_pred[i,0]<0.5:
            count1+=1
print(count,count1)
# Out:
# 19/19 [==============================] - 0s 1ms/step
# 304 283

# %% [markdown]
# ## GDA

# %%
import numpy as np
from scipy.stats import multivariate_normal

class GaussianDiscriminantAnalysis:
    def fit(self, X, y):
        self.classes = np.unique(y)
        self.class_priors = np.array([np.mean(y == c) for c in self.classes])

        self.means = []
        self.cov_matrices = []
        for c in self.classes:
            X_c = X[y == c]
            mean_c = np.mean(X_c, axis=0)
            cov_matrix_c = np.cov(X_c, rowvar=False)
            self.means.append(mean_c)
            self.cov_matrices.append(cov_matrix_c)

    def predict(self, X):
        posteriors = []

        for c in self.classes:
            class_prior = self.class_priors[int(c)]
            mean = self.means[int(c)]
            cov_matrix = self.cov_matrices[int(c)]
            mvn = multivariate_normal(mean=mean, cov=cov_matrix)
            posterior = class_prior * mvn.pdf(X)
            posteriors.append(posterior)

        posteriors = np.array(posteriors).T
        predicted_labels = np.argmax(posteriors, axis=1)

        return predicted_labels



# Initialize and train GDA
gda = GaussianDiscriminantAnalysis()
gda.fit(x_train, y_train)

# Make predictions
y_pred = gda.predict(x_train)
# Calculate accuracy
accuracy = np.mean(y_pred == y_train)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 92.21%
