# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential,load_model
from keras import layers
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from keras.callbacks import ModelCheckpoint

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## Load

# %%
x=np.load('20240711/train-001.npy')

# %%
INTEGRATION_LENGTH = 2200
integeration_start = 142


with open('20240711/train-001.npy', 'rb') as file:
    train_data = np.load(file, allow_pickle=False)[:,:, integeration_start:integeration_start+INTEGRATION_LENGTH]

n_reps, n_levels, n_sample_points = train_data.shape


train_label = np.array([[[l] for l in range(n_levels)] for _ in range(n_reps)])
train_data_acc = train_data.mean(axis=-1)


with open('20240711/test.npy', 'rb') as file:
    test_data = np.load(file, allow_pickle=False)[:,:, integeration_start:integeration_start+INTEGRATION_LENGTH]

n_reps, n_levels, n_sample_points = test_data.shape


test_label = np.array([[[l] for l in range(n_levels)] for _ in range(n_reps)])
test_data_acc = test_data.mean(axis=-1)

# %% [markdown]
# ## NN

# %%
train_data.shape
train_label.shape
# Out:
# (8000, 10, 1)

# %%
x=train_data.reshape(-1,train_data.shape[-1])
X=np.hstack((x.real,x.imag))
y=train_label.reshape(-1)
X.shape, y.shape
# Out:
# ((80000, 4400), (80000,))

# %%
y = to_categorical(y, num_classes=10)

# %%
model = Sequential()
model.add(layers.Input(shape=(4400,), name='Input_Layer'))
model.add(layers.Dense(512, activation='relu', name='Hidden_Layer_1'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation='relu', name='Hidden_Layer_2'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu', name='Hidden_Layer_3'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax', name='Output_Layer'))


# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001,use_ema=True)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001)

model_path="model/{epoch:02d}-{val_loss:.4f}-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint,reduce_lr]
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden_Layer_1 (Dense)      (None, 256)               1126656
#
#  Hidden_Layer_2 (Dense)      (None, 128)               32896
#
#  Output_Layer (Dense)        (None, 10)                1290
#
# =================================================================
# Total params: 1160842 (4.43 MB)
# Trainable params: 1160842 (4.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
model.fit(X, y, epochs=100, batch_size=1024, validation_split=0.2, callbacks=callbacks_list,)
# Out:
# Epoch 1/100
# 56/63 [=========================>....] - ETA: 0s - loss: 1.8222 - accuracy: 0.5332
# Epoch 1: val_accuracy improved from -inf to 0.81406, saving model to model/01-1.0792-0.8141.h5
# 63/63 [==============================] - 2s 20ms/step - loss: 1.7526 - accuracy: 0.5598 - val_loss: 1.0792 - val_accuracy: 0.8141
# Epoch 2/100
# 25/63 [==========>...................] - ETA: 0s - loss: 0.8335 - accuracy: 0.8523
# /global/homes/n/nrvora/.conda/envs/readout/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 61/63 [============================>.] - ETA: 0s - loss: 0.6401 - accuracy: 0.8751
# Epoch 2: val_accuracy improved from 0.81406 to 0.89800, saving model to model/02-0.4257-0.8980.h5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6344 - accuracy: 0.8759 - val_loss: 0.4257 - val_accuracy: 0.8980
# Epoch 3/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.3315 - accuracy: 0.9155
# Epoch 3: val_accuracy improved from 0.89800 to 0.91644, saving model to model/03-0.3156-0.9164.h5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3281 - accuracy: 0.9157 - val_loss: 0.3156 - val_accuracy: 0.9164
# Epoch 4/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.2542 - accuracy: 0.9313
# Epoch 4: val_accuracy improved from 0.91644 to 0.92481, saving model to model/04-0.2705-0.9248.h5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2527 - accuracy: 0.9312 - val_loss: 0.2705 - val_accuracy: 0.9248
# Epoch 5/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.2121 - accuracy: 0.9392
# Epoch 5: val_accuracy improved from 0.92481 to 0.92931, saving model to model/05-0.2470-0.9293.h5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.2120 - accuracy: 0.9392 - val_loss: 0.2470 - val_accuracy: 0.9293
# Epoch 6/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1857 - accuracy: 0.9461
# Epoch 6: val_accuracy improved from 0.92931 to 0.93012, saving model to model/06-0.2379-0.9301.h5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1855 - accuracy: 0.9458 - val_loss: 0.2379 - val_accuracy: 0.9301
# Epoch 7/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1651 - accuracy: 0.9507
# Epoch 7: val_accuracy improved from 0.93012 to 0.93313, saving model to model/07-0.2291-0.9331.h5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1654 - accuracy: 0.9506 - val_loss: 0.2291 - val_accuracy: 0.9331
# Epoch 8/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.1521 - accuracy: 0.9541
# Epoch 8: val_accuracy improved from 0.93313 to 0.93469, saving model to model/08-0.2264-0.9347.h5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1510 - accuracy: 0.9546 - val_loss: 0.2264 - val_accuracy: 0.9347
# Epoch 9/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1362 - accuracy: 0.9588
# Epoch 9: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1358 - accuracy: 0.9588 - val_loss: 0.2258 - val_accuracy: 0.9302
# Epoch 10/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.1248 - accuracy: 0.9624
# Epoch 10: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1245 - accuracy: 0.9625 - val_loss: 0.2407 - val_accuracy: 0.9277
# Epoch 11/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.1147 - accuracy: 0.9648
# Epoch 11: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1157 - accuracy: 0.9646 - val_loss: 0.2262 - val_accuracy: 0.9295
# Epoch 12/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.1045 - accuracy: 0.9685
# Epoch 12: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1052 - accuracy: 0.9685 - val_loss: 0.2356 - val_accuracy: 0.9270
# Epoch 13/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.0989 - accuracy: 0.9706
# Epoch 13: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0986 - accuracy: 0.9706 - val_loss: 0.2366 - val_accuracy: 0.9234
# Epoch 14/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0921 - accuracy: 0.9721
# Epoch 14: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0928 - accuracy: 0.9719 - val_loss: 0.2539 - val_accuracy: 0.9221
# Epoch 15/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0867 - accuracy: 0.9736
# Epoch 15: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0866 - accuracy: 0.9737 - val_loss: 0.2509 - val_accuracy: 0.9187
# Epoch 16/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.0798 - accuracy: 0.9766
# Epoch 16: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0796 - accuracy: 0.9767 - val_loss: 0.2574 - val_accuracy: 0.9167
# Epoch 17/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0740 - accuracy: 0.9785
# Epoch 17: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0750 - accuracy: 0.9778 - val_loss: 0.2599 - val_accuracy: 0.9212
# Epoch 18/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0692 - accuracy: 0.9804
# Epoch 18: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0693 - accuracy: 0.9802 - val_loss: 0.2675 - val_accuracy: 0.9161
# Epoch 19/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0643 - accuracy: 0.9821
# Epoch 19: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0642 - accuracy: 0.9822 - val_loss: 0.2739 - val_accuracy: 0.9158
# Epoch 20/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.0600 - accuracy: 0.9838
# Epoch 20: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0611 - accuracy: 0.9831 - val_loss: 0.2918 - val_accuracy: 0.9119
# Epoch 21/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.0585 - accuracy: 0.9838
# Epoch 21: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0582 - accuracy: 0.9837 - val_loss: 0.2868 - val_accuracy: 0.9177
# Epoch 22/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.0524 - accuracy: 0.9860
# Epoch 22: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0533 - accuracy: 0.9855 - val_loss: 0.2980 - val_accuracy: 0.9158
# Epoch 23/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.0485 - accuracy: 0.9875
# Epoch 23: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0499 - accuracy: 0.9865 - val_loss: 0.3102 - val_accuracy: 0.9139
# Epoch 24/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.0459 - accuracy: 0.9883
# Epoch 24: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0470 - accuracy: 0.9873 - val_loss: 0.3141 - val_accuracy: 0.9122
# Epoch 25/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.0442 - accuracy: 0.9883
# Epoch 25: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0445 - accuracy: 0.9881 - val_loss: 0.3235 - val_accuracy: 0.9141
# Epoch 26/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.0409 - accuracy: 0.9897
# Epoch 26: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0416 - accuracy: 0.9892 - val_loss: 0.3300 - val_accuracy: 0.9137
# Epoch 27/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9907
# Epoch 27: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0382 - accuracy: 0.9907 - val_loss: 0.3378 - val_accuracy: 0.9112
# Epoch 28/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.0357 - accuracy: 0.9917
# Epoch 28: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0357 - accuracy: 0.9916 - val_loss: 0.3479 - val_accuracy: 0.9106
# Epoch 29/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.0330 - accuracy: 0.9925
# Epoch 29: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0340 - accuracy: 0.9920 - val_loss: 0.3657 - val_accuracy: 0.9079
# Epoch 30/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0346 - accuracy: 0.9907
# Epoch 30: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0348 - accuracy: 0.9905 - val_loss: 0.3687 - val_accuracy: 0.9091
# Epoch 31/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9922
# Epoch 31: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0312 - accuracy: 0.9922 - val_loss: 0.3743 - val_accuracy: 0.9104
# Epoch 32/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.0274 - accuracy: 0.9943
# Epoch 32: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0277 - accuracy: 0.9940 - val_loss: 0.3790 - val_accuracy: 0.9105
# Epoch 33/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9942
# Epoch 33: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0262 - accuracy: 0.9942 - val_loss: 0.3921 - val_accuracy: 0.9099
# Epoch 34/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0244 - accuracy: 0.9951
# Epoch 34: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0246 - accuracy: 0.9949 - val_loss: 0.4029 - val_accuracy: 0.9061
# Epoch 35/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0236 - accuracy: 0.9947
# Epoch 35: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0236 - accuracy: 0.9947 - val_loss: 0.4091 - val_accuracy: 0.9062
# Epoch 36/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0207 - accuracy: 0.9962
# Epoch 36: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0211 - accuracy: 0.9960 - val_loss: 0.4226 - val_accuracy: 0.9075
# Epoch 37/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0202 - accuracy: 0.9961
# Epoch 37: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0203 - accuracy: 0.9960 - val_loss: 0.4340 - val_accuracy: 0.9056
# Epoch 38/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.0184 - accuracy: 0.9967
# Epoch 38: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0186 - accuracy: 0.9967 - val_loss: 0.4410 - val_accuracy: 0.9066
# Epoch 39/100
# 54/63 [========================>.....] - ETA: 0s - loss: 0.0163 - accuracy: 0.9979
# Epoch 39: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0166 - accuracy: 0.9976 - val_loss: 0.4558 - val_accuracy: 0.9039
# Epoch 40/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0168 - accuracy: 0.9969
# Epoch 40: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0170 - accuracy: 0.9968 - val_loss: 0.4662 - val_accuracy: 0.9043
# Epoch 41/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0151 - accuracy: 0.9975
# Epoch 41: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 0.9975 - val_loss: 0.4703 - val_accuracy: 0.9052
# Epoch 42/100
# 58/63 [==========================>...] - ETA: 0s - loss: 0.0127 - accuracy: 0.9988
# Epoch 42: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0128 - accuracy: 0.9987 - val_loss: 0.4826 - val_accuracy: 0.9055
# Epoch 43/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9986
# Epoch 43: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0120 - accuracy: 0.9987 - val_loss: 0.4859 - val_accuracy: 0.9049
# Epoch 44/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.9988
# Epoch 44: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0116 - accuracy: 0.9987 - val_loss: 0.5067 - val_accuracy: 0.9032
# Epoch 45/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9990
# Epoch 45: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0106 - accuracy: 0.9990 - val_loss: 0.5081 - val_accuracy: 0.9044
# Epoch 46/100
# 51/63 [=======================>......] - ETA: 0s - loss: 0.0089 - accuracy: 0.9995
# Epoch 46: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 0.9993 - val_loss: 0.5152 - val_accuracy: 0.9053
# Epoch 47/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.0088 - accuracy: 0.9994
# Epoch 47: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0088 - accuracy: 0.9994 - val_loss: 0.5261 - val_accuracy: 0.9062
# Epoch 48/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9998
# Epoch 48: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 0.9998 - val_loss: 0.5321 - val_accuracy: 0.9039
# Epoch 49/100
# 51/63 [=======================>......] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.9041
# Epoch 50/100
# 60/63 [===========================>..] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.9039
# Epoch 51/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5608 - val_accuracy: 0.9043
# Epoch 52/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.5678 - val_accuracy: 0.9042
# Epoch 53/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5777 - val_accuracy: 0.9036
# Epoch 54/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5836 - val_accuracy: 0.9042
# Epoch 55/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.5899 - val_accuracy: 0.9043
# Epoch 56/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.5999 - val_accuracy: 0.9041
# Epoch 57/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.6068 - val_accuracy: 0.9039
# Epoch 58/100
# 54/63 [========================>.....] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.6144 - val_accuracy: 0.9031
# Epoch 59/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6234 - val_accuracy: 0.9031
# Epoch 60/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6314 - val_accuracy: 0.9027
# Epoch 61/100
# 57/63 [==========================>...] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6362 - val_accuracy: 0.9034
# Epoch 62/100
# 61/63 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6419 - val_accuracy: 0.9032
# Epoch 63/100
# 62/63 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6498 - val_accuracy: 0.9030
# Epoch 64/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6518 - val_accuracy: 0.9033
# Epoch 65/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6613 - val_accuracy: 0.9035
# Epoch 66/100
# 51/63 [=======================>......] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6688 - val_accuracy: 0.9027
# Epoch 67/100
# 52/63 [=======================>......] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6767 - val_accuracy: 0.9029
# Epoch 68/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6815 - val_accuracy: 0.9026
# Epoch 69/100
# 59/63 [===========================>..] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6861 - val_accuracy: 0.9031
# Epoch 70/100
# 63/63 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6972 - val_accuracy: 0.9026
# Epoch 71/100
# 51/63 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6993 - val_accuracy: 0.9027
# Epoch 72/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7050 - val_accuracy: 0.9024
# Epoch 73/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.7113 - val_accuracy: 0.9024
# Epoch 74/100
# 52/63 [=======================>......] - ETA: 0s - loss: 9.8864e-04 - accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 9.9281e-04 - accuracy: 1.0000 - val_loss: 0.7132 - val_accuracy: 0.9026
# Epoch 75/100
# 57/63 [==========================>...] - ETA: 0s - loss: 9.4978e-04 - accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 9.5599e-04 - accuracy: 1.0000 - val_loss: 0.7238 - val_accuracy: 0.9028
# Epoch 76/100
# 52/63 [=======================>......] - ETA: 0s - loss: 9.0184e-04 - accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 9.0885e-04 - accuracy: 1.0000 - val_loss: 0.7282 - val_accuracy: 0.9020
# Epoch 77/100
# 52/63 [=======================>......] - ETA: 0s - loss: 8.2429e-04 - accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 8.3056e-04 - accuracy: 1.0000 - val_loss: 0.7321 - val_accuracy: 0.9026
# Epoch 78/100
# 52/63 [=======================>......] - ETA: 0s - loss: 7.7631e-04 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 7.8596e-04 - accuracy: 1.0000 - val_loss: 0.7363 - val_accuracy: 0.9026
# Epoch 79/100
# 61/63 [============================>.] - ETA: 0s - loss: 7.3878e-04 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 9ms/step - loss: 7.4039e-04 - accuracy: 1.0000 - val_loss: 0.7415 - val_accuracy: 0.9029
# Epoch 80/100
# 60/63 [===========================>..] - ETA: 0s - loss: 6.9305e-04 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 6.9630e-04 - accuracy: 1.0000 - val_loss: 0.7495 - val_accuracy: 0.9028
# Epoch 81/100
# 59/63 [===========================>..] - ETA: 0s - loss: 6.6356e-04 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 6.6331e-04 - accuracy: 1.0000 - val_loss: 0.7545 - val_accuracy: 0.9018
# Epoch 82/100
# 58/63 [==========================>...] - ETA: 0s - loss: 6.2940e-04 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 6.3183e-04 - accuracy: 1.0000 - val_loss: 0.7573 - val_accuracy: 0.9021
# Epoch 83/100
# 61/63 [============================>.] - ETA: 0s - loss: 6.0356e-04 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 6.0152e-04 - accuracy: 1.0000 - val_loss: 0.7617 - val_accuracy: 0.9027
# Epoch 84/100
# 53/63 [========================>.....] - ETA: 0s - loss: 5.6905e-04 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 5.7745e-04 - accuracy: 1.0000 - val_loss: 0.7685 - val_accuracy: 0.9019
# Epoch 85/100
# 53/63 [========================>.....] - ETA: 0s - loss: 5.4539e-04 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 5.4483e-04 - accuracy: 1.0000 - val_loss: 0.7723 - val_accuracy: 0.9025
# Epoch 86/100
# 58/63 [==========================>...] - ETA: 0s - loss: 5.0672e-04 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 5.0986e-04 - accuracy: 1.0000 - val_loss: 0.7769 - val_accuracy: 0.9030
# Epoch 87/100
# 53/63 [========================>.....] - ETA: 0s - loss: 4.8122e-04 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 4.8775e-04 - accuracy: 1.0000 - val_loss: 0.7830 - val_accuracy: 0.9019
# Epoch 88/100
# 58/63 [==========================>...] - ETA: 0s - loss: 4.6715e-04 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 4.6828e-04 - accuracy: 1.0000 - val_loss: 0.7859 - val_accuracy: 0.9020
# Epoch 89/100
# 52/63 [=======================>......] - ETA: 0s - loss: 4.4041e-04 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 4.4658e-04 - accuracy: 1.0000 - val_loss: 0.7951 - val_accuracy: 0.9022
# Epoch 90/100
# 52/63 [=======================>......] - ETA: 0s - loss: 4.1761e-04 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 4.1802e-04 - accuracy: 1.0000 - val_loss: 0.7965 - val_accuracy: 0.9024
# Epoch 91/100
# 59/63 [===========================>..] - ETA: 0s - loss: 3.9761e-04 - accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 3.9837e-04 - accuracy: 1.0000 - val_loss: 0.8033 - val_accuracy: 0.9024
# Epoch 92/100
# 55/63 [=========================>....] - ETA: 0s - loss: 3.7299e-04 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 3.7625e-04 - accuracy: 1.0000 - val_loss: 0.8083 - val_accuracy: 0.9018
# Epoch 93/100
# 56/63 [=========================>....] - ETA: 0s - loss: 3.6088e-04 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 8ms/step - loss: 3.6018e-04 - accuracy: 1.0000 - val_loss: 0.8105 - val_accuracy: 0.9022
# Epoch 94/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4216e-04 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 3.4216e-04 - accuracy: 1.0000 - val_loss: 0.8170 - val_accuracy: 0.9021
# Epoch 95/100
# 56/63 [=========================>....] - ETA: 0s - loss: 3.2478e-04 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 3.2663e-04 - accuracy: 1.0000 - val_loss: 0.8190 - val_accuracy: 0.9018
# Epoch 96/100
# 53/63 [========================>.....] - ETA: 0s - loss: 3.1075e-04 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 8ms/step - loss: 3.1219e-04 - accuracy: 1.0000 - val_loss: 0.8254 - val_accuracy: 0.9022
# Epoch 97/100
# 52/63 [=======================>......] - ETA: 0s - loss: 2.9682e-04 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 6ms/step - loss: 3.0069e-04 - accuracy: 1.0000 - val_loss: 0.8304 - val_accuracy: 0.9012
# Epoch 98/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8414e-04 - accuracy: 1.0000
# Epoch 98: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 2.8414e-04 - accuracy: 1.0000 - val_loss: 0.8339 - val_accuracy: 0.9017
# Epoch 99/100
# 56/63 [=========================>....] - ETA: 0s - loss: 2.7012e-04 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 0s 7ms/step - loss: 2.7053e-04 - accuracy: 1.0000 - val_loss: 0.8388 - val_accuracy: 0.9013
# Epoch 100/100
# 62/63 [============================>.] - ETA: 0s - loss: 2.6123e-04 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 0.93469
# 63/63 [==============================] - 1s 10ms/step - loss: 2.6114e-04 - accuracy: 1.0000 - val_loss: 0.8419 - val_accuracy: 0.9018

# %%
x_test=test_data.reshape(-1,test_data.shape[-1])
X_test=np.hstack((x_test.real,x_test.imag))
y_test=test_label.reshape(-1)
y_test = to_categorical(y_test, num_classes=10)
X_test.shape, y_test.shape
# Out:
# ((20000, 4400), (20000, 10))

# %%
model = load_model('model/08-0.2264-0.9347.h5', compile=False)
Y_pred = model.predict(X_test)

# Convert one-hot encoded predictions back to label format
Y_test_labels = np.argmax(y_test, axis=1)
Y_pred_labels = np.argmax(Y_pred, axis=1)

# Generate the confusion matrix
conf_matrix = confusion_matrix(Y_test_labels, Y_pred_labels)

# Normalize the confusion matrix to percentage
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

# Display the normalized confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_normalized, display_labels=np.arange(10))
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (in Percentage)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(10), labels=np.arange(10))
plt.yticks(np.arange(10), labels=np.arange(10))
plt.show()

accuracy = accuracy_score(Y_test_labels, Y_pred_labels)
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# 625/625 [==============================] - 1s 855us/step
# Test Accuracy: 93.38%

# %%
conf_matrix
# Out:
# array([[1982,    0,    0,    3,    0,    0,    2,   12,    1,    0],
#        [   0, 1977,   16,    0,    0,    0,    0,    0,    0,    7],
#        [   0,  121, 1875,    0,    0,    0,    0,    0,    0,    4],
#        [  22,    0,    0, 1929,   17,   25,    0,    7,    0,    0],
#        [  28,    0,    0,   64, 1854,   51,    1,    0,    2,    0],
#        [  17,    0,    0,   58,   37, 1837,   50,    1,    0,    0],
#        [  15,    0,    0,   12,    0,  116, 1752,  105,    0,    0],
#        [  23,    0,    0,   16,    1,   27,  314, 1614,    5,    0],
#        [  23,    0,    0,    5,   20,   22,    5,   20, 1905,    0],
#        [   0,   24,   35,    0,    0,    1,    1,    0,    0, 1939]])
